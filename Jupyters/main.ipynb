# %%
import pandas as pd
import requests as req
import glob
import numpy as np

# %%
# Carpeta que contiene los archivos CSV
carpeta = r'C:\Users\filokaizen\OneDrive - Tajamar\Desktop\ii\last-project\Data'

# Obtener la lista de archivos CSV en la carpeta
archivos_csv = glob.glob(carpeta + "/*.csv")

# Verificar si se encontraron archivos CSV en la carpeta
if len(archivos_csv) == 0:
    print("No se encontraron archivos CSV en la carpeta especificada.")
else:
    # Lista para almacenar los DataFrames cargados
    dfs = []

    # Bucle para cargar cada archivo CSV en un DataFrame
    for archivo in archivos_csv:
        data = pd.read_csv(archivo)
        dfs.append(data)

    # Concatenar los DataFrames en uno solo
    data = pd.concat(dfs)

# %%
data.columns = [e.lower().strip().replace(" ", "")for e in data.columns]
# e.lower : pongo todo en minúsculas
#strip, sustituye en ambos lados

# %%
# data["primera_palabra"] = data["ubicación"].str.split().str[0]
# #Dividimos la columna ubicación en palabras y solo elegimos las primera 
# # Crea una nueva columna llamada "Primera Palabra" y

# %%
# Creo una nueva columna que sea tipo de vivienda
data["tipo_vivienda"] = np.where(data["ubicación"].str.contains("Piso|Apartamento"), "Piso",
                    np.where(data["ubicación"].str.contains("Chalet|Casa"), "Chalet",
                    np.where(data["ubicación"].str.contains ("Duplex"), "Duplex",
                    np.where(data["ubicación"].str.contains ("Ático"), "Ático",
                    np.where(data["ubicación"].str.contains("Estudio"), "Estudio", "Otro")))))

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 660 entries, 0 to 29
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ubicación      660 non-null    object
#  1   precio         660 non-null    object
#  2   detalles       660 non-null    object
#  3   tipo_vivienda  660 non-null    object
# dtypes: object(4)
# memory usage: 25.8+ KB

# %%
## Selecciono solo la palabra anterior a Madrid para sacar los barrios 
data["palabra_anterior"] = data["ubicación"].str.extract(r'(\w+)\s Madrid', expand=False)

# %%
data["ubicación"].unique()
# Out:
# array(['Piso en calle de Jesús y María  Lavapiés-Embajadores  Madrid',
#        'Piso en calle de Cardenal Mendoza  Puerta del Ángel  Madrid',
#        'Piso en calle del Olivar  44  Lavapiés-Embajadores  Madrid',
#        'Piso en calle Solana de Luche  Puerta del Ángel  Madrid',
#        'Piso en Atlético de Madrid 2  2  Puerta Bonita  Madrid',
#        'Piso en calle industria  Puerta del Ángel  Madrid',
#        'Piso en calle de San Vicente Ferrer  Malasaña-Universidad  Madrid',
#        'Piso en Nuevos Ministerios-Ríos Rosas  Madrid',
#        'Piso en Blasco de Garay  Arapiles  Madrid',
#        'Piso en calle del Pintor Ignacio de Zuloaga  2  Sanchinarro  Madrid',
#        'Piso en calle Minas  7  Malasaña-Universidad  Madrid',
#        'Piso en Berruguete  Berruguete  Madrid',
#        'Piso en Recoletos  Madrid',
#        'Piso en calle de Carranza  4  Trafalgar  Madrid',
#        'Piso en calle de Amaniel  Malasaña-Universidad  Madrid',
#        'Piso en calle de la Virgen de los Peligros  Huertas-Cortes  Madrid',
#        'Estudio en Quintana  Madrid',
#        'Piso en calle de Alfonso VI  6  Palacio  Madrid',
#        'Ático en calle de Ángel Muñoz  San Juan Bautista  Madrid',
#        'Piso en Huertas-Cortes  Madrid',
#        'Piso en calle de bravo Murillo  297  Valdeacederas  Madrid',
#        'Dúplex en calle de Palafox  Trafalgar  Madrid',
#        'Piso en Bernabéu-Hispanoamérica  Madrid',
#        'Estudio en calle de San Lorenzo  Chueca-Justicia  Madrid',
#        'Piso en Goya  Madrid',
#        'Piso en calle de San Bernardo  Malasaña-Universidad  Madrid',
#        'Dúplex en paseo de Juan XXIII  40  Ciudad Universitaria  Madrid',
#        'Piso en Vicente Muzas  Colina  Madrid',
#        'Piso en calle de Coslada  11  Guindalera  Madrid',
#        'Piso en paseo de la Castellana  Ventilla-Almenara  Madrid',
#        'Piso en calle Villa del Prado  Delicias  Madrid',
#        'Piso en Ibiza  Madrid',
#        'Piso en calle Alonso Heredia  29  Guindalera  Madrid',
#        'Casa o chalet independiente en El Plantío  Madrid',
#        'Piso en calle Sagasta  Trafalgar  Madrid',
#        'Piso en calle de Jesús de Polanco  Peñagrande  Madrid',
#        'Piso en Conde de Aranda  10  Recoletos  Madrid',
#        'Piso en calle de Hermosilla  Goya  Madrid',
#        'Piso en plaza de Arteijo  13  Pilar  Madrid',
#        'Piso en paseo de la Infanta Isabel  Jerónimos  Madrid',
#        'Piso en Serrano  112  Castellana  Madrid',
#        'Dúplex en calle del Príncipe de Vergara  Castellana  Madrid',
#        'Ático en calle Ferraz  37  Argüelles  Madrid',
#        'Piso en calle de Pavía  Palacio  Madrid',
#        'Piso en calle de Antonio de Leyva  76  Opañel  Madrid',
#        'Piso en yecora  Rejas  Madrid',
#        'Ático en San Carlos  6  Lavapiés-Embajadores  Madrid',
#        'Piso en calle de Lope de Vega  Huertas-Cortes  Madrid',
#        'Piso en plaza de Corcubión  1  Pilar  Madrid',
#        'Piso en avenida de los Andes  Conde Orgaz-Piovera  Madrid',
#        'Dúplex en calle de Vallehermoso  104  Vallehermoso  Madrid',
#        'Piso en avenida de los Madroños  Conde Orgaz-Piovera  Madrid',
#        'Piso en calle de las Delicias  Palos de Moguer  Madrid',
#        'Estudio en calle de Lagasca  Recoletos  Madrid',
#        'Piso en calle Cabo Nicolás Mur  San Isidro  Madrid',
#        'Ático en calle de Arganzuela  Lavapiés-Embajadores  Madrid',
#        'Piso en calle del Doctor Cortezo  Lavapiés-Embajadores  Madrid',
#        'Ático en plaza del Ángel  Huertas-Cortes  Madrid',
#        'Piso en calle de la Infanta Mercedes  Cuatro Caminos  Madrid',
#        'Piso en calle de Calatrava  Palacio  Madrid',
#        'Piso en calle de Fray José Cerdeiriña  Águilas  Madrid',
#        'Piso en calle villamanin  Lucero  Madrid',
#        'Estudio en calle de Arganzuela  Lavapiés-Embajadores  Madrid',
#        'Piso en calle del Apóstol Santiago  68  Ventas  Madrid',
#        'Piso en calle de Arganzuela  Lavapiés-Embajadores  Madrid',
#        'Piso en Poeta Joan Maragall  Cuzco-Castillejos  Madrid',
#        'Piso en calle del Carmen  Sol  Madrid',
#        'Piso en Nuñez de Balboa  56  Recoletos  Madrid',
#        'Piso en calle de Alejandro Saint Aubin  Chopera  Madrid',
#        'Dúplex en Mirasierra  Madrid', 'Piso en Guindalera  Madrid',
#        'Piso en calle de la Oca  Vista Alegre  Madrid',
#        'Piso en calle de Barrilero  Adelfas  Madrid',
#        'Dúplex en paseo de la Direccion  Berruguete  Madrid',
#        'Piso en Palacio  Madrid',
#        'Piso en calle de Wad-Ras  Bellas Vistas  Madrid',
#        'Piso en calle de Tortosa  Palos de Moguer  Madrid',
#        'Piso en calle del Barco  9  Malasaña-Universidad  Madrid',
#        'Piso en Almagro  Madrid', 'Piso en Segovia  Palacio  Madrid',
#        'Ático en Ciudad Jardín  Madrid',
#        'Piso en calle de Sánchez Barcáiztegui  Pacífico  Madrid',
#        'Piso en calle de la Sierra de los Filabres  37  Numancia  Madrid',
#        'Chalet adosado en Aravaca  Madrid',
#        'Estudio en calle Galería de Robles  Malasaña-Universidad  Madrid',
#        'Piso en calle de Valencia  Lavapiés-Embajadores  Madrid',
#        'Piso en paseo de Santa María de la Cabeza  Chopera  Madrid',
#        'Estudio en calle Embalse de Navacerrada  Ensanche de Vallecas - La Gavia  Madrid',
#        'Piso en calle Sandalio López  Tres Olivos - Valverde  Madrid',
#        'Piso en calle Martínez Corrochano  29  Adelfas  Madrid',
#        'Piso en Jerte  Palacio  Madrid',
#        'Piso en plaza de Andrés Manjón  7  Castilla  Madrid',
#        'Piso en calle de la Reina Mercedes  8  Cuatro Caminos  Madrid',
#        'Piso en calle de Bretón de los Herreros  20  Nuevos Ministerios-Ríos Rosas  Madrid',
#        'Piso en calle de Aniceto Pérez  12 de Octubre-Orcasur  Madrid',
#        'Ático en calle de Luchana  Trafalgar  Madrid',
#        'Piso en calle de la Ribera de Curtidores  Lavapiés-Embajadores  Madrid',
#        'Piso en calle Calatrava  Palacio  Madrid',
#        'Estudio en Malasaña-Universidad  Madrid',
#        'Estudio en calle Mayor  Sol  Madrid',
#        'Piso en calle de Ibiza  Ibiza  Madrid',
#        'Piso en calle del Marqués de Mondéjar  Fuente del Berro  Madrid',
#        'Ático en calle de Alcántara  Lista  Madrid',
#        'Piso en calle Tírvia  Ciudad Universitaria  Madrid',
#        'Piso en Calamón  Campamento  Madrid',
#        'Ático en calle de la Princesa  26  Malasaña-Universidad  Madrid',
#        'Dúplex en san Juan de Ortega  100  Las Tablas  Madrid',
#        'Estudio en Lagasca  Recoletos  Madrid',
#        'Estudio en calle de Don Ramón de la Cruz  62  Goya  Madrid',
#        'Piso en ronda de Segovia  50  Imperial  Madrid',
#        'Piso en paseo San Francisco de Sales  Vallehermoso  Madrid',
#        'Piso en calle de Costa Rica  14  Bernabéu-Hispanoamérica  Madrid',
#        'Piso en Ignacio Ellacuria  18  Ventas  Madrid',
#        'Piso en calle Sierra de Pajarejo  7  Valdemarín  Madrid',
#        'Chalet pareado en calle de Formigal  Valdemarín  Madrid',
#        'Piso en avenida Betanzos  Pilar  Madrid',
#        'Piso en calle Mozart  Casa de Campo  Madrid',
#        'Piso en calle de Altamirano  6  Argüelles  Madrid',
#        'Piso en calle del Monte Urgull  Numancia  Madrid',
#        'Piso en calle de Oliva de Plasencia  Águilas  Madrid',
#        'Piso en Trafalgar  Madrid',
#        'Piso en avenida de la Aviación  Águilas  Madrid',
#        'Piso en paseo de la Dirección  Valdeacederas  Madrid',
#        'Piso en zurron  12  Timón  Madrid',
#        'Piso en calle de García de Paredes  Almagro  Madrid',
#        'Ático en calle del Olmo  25  Lavapiés-Embajadores  Madrid',
#        'Dúplex en calle de San Bernardo  Malasaña-Universidad  Madrid',
#        'Dúplex en plaza de Tuy  Pilar  Madrid', 'Piso en Lista  Madrid',
#        'Piso en paseo de Extremadura  Puerta del Ángel  Madrid',
#        'Piso en plaza de las Cortes  Huertas-Cortes  Madrid',
#        'Piso en calle Marmolistas  Arcos  Madrid',
#        'Piso en calle San Valero  Numancia  Madrid',
#        'Ático en calle Archiduque Alberto  23  Sanchinarro  Madrid',
#        'Piso en calle de Manuel Maroto  San Diego  Madrid',
#        'Piso en calle Alcalde Sáenz de Baranda  Ibiza  Madrid',
#        'Piso en avenida de América  Prosperidad  Madrid',
#        'Casa o chalet independiente en calle de Arévalo Lara  Salvador  Madrid',
#        'Piso en calle Manuel María Iglesias  San Juan Bautista  Madrid',
#        'Piso en Soto Hidalgo  4  Alameda de Osuna  Madrid',
#        'Piso en calle de Cartagena  Guindalera  Madrid',
#        'Piso en calle Santiago Cuende  5  Puerta Bonita  Madrid',
#        'Piso en calle de Diego de León  Castellana  Madrid',
#        'Casa o chalet independiente en Conde Orgaz-Piovera  Madrid',
#        'Piso en Peñagrande  Madrid',
#        'Ático en plaza de Juan Zorrilla  Vallehermoso  Madrid',
#        "Ático en calle de O'Donnell  40  Ibiza  Madrid",
#        'Piso en calle de Santa Isabel  42  Lavapiés-Embajadores  Madrid',
#        'Piso en Cava Baja  Palacio  Madrid',
#        'Piso en calle del Divino Pastor  Malasaña-Universidad  Madrid',
#        'Piso en calle de la Villa de Marín  29  La Paz  Madrid',
#        'Piso en calle Donoso Cortés  Gaztambide  Madrid',
#        'Piso en calle del Puerto del Bruch  Casco Histórico de Vallecas  Madrid',
#        'Piso en avenida del talgo  Aravaca  Madrid',
#        'Piso en calle de Dulce Chacón  Virgen del Cortijo - Manoteras  Madrid',
#        'Piso en Estrella  Madrid',
#        'Piso en Arturo soria  Costillares  Madrid',
#        'Piso en calle Anna Frank  19  El Cañaveral  Madrid',
#        'Piso en calle del Espíritu Santo  24  Malasaña-Universidad  Madrid',
#        'Piso en Malasaña-Universidad  Madrid',
#        'Piso en calle de Joaquín Martín  Opañel  Madrid',
#        'Piso en Castilla  Madrid',
#        'Piso en avenida de Secundino Zuazo  73  Valdebebas - Valdefuentes  Madrid',
#        'Piso en Argüelles  Madrid',
#        'Piso en calle de Ocaña  56  Aluche  Madrid',
#        'Piso en calle de Tribulete  Lavapiés-Embajadores  Madrid',
#        'Piso en avenida Moratalaz  Vinateros  Madrid',
#        'Piso en calle del Olivar  Lavapiés-Embajadores  Madrid',
#        'Piso en paseo de Santa María de la Cabeza  124  Comillas  Madrid',
#        'Piso en calle del Prado  Huertas-Cortes  Madrid',
#        'Dúplex en calle de la ribera de curtidores  16  Lavapiés-Embajadores  Madrid',
#        'Piso en calle de Francisco Silvela  Lista  Madrid',
#        'Piso en Paseo De La Castellana  201  Ventilla-Almenara  Madrid',
#        'Piso en Lavapiés-Embajadores  Madrid',
#        'Piso en paseo Castellana  203  Ventilla-Almenara  Madrid',
#        'Piso en calle del General Margallo  24  Cuzco-Castillejos  Madrid',
#        'Piso en calle del Gasómetro  Acacias  Madrid',
#        'Piso en calle de Camarena  112  Aluche  Madrid',
#        'Piso en calle de Astorga  Ventas  Madrid',
#        'Piso en paseo de La Habana  46  El Viso  Madrid',
#        'Piso en alameda de osuna  50  Alameda de Osuna  Madrid',
#        'Piso en paseo de La Habana  Bernabéu-Hispanoamérica  Madrid',
#        'Piso en calle del Conde de Aranda  Recoletos  Madrid',
#        'Piso en calle de la Costa Brava  47  Mirasierra  Madrid',
#        'Piso en El Santo de la Isidra  10  Los Ángeles  Madrid',
#        'Piso en calle de Federico Grases  Puerta Bonita  Madrid',
#        'Piso en Canillas  Madrid',
#        'Piso en calle San Severo  s/n  Alameda de Osuna  Madrid',
#        'Piso en calle la Granja de San Ildefonso  28  Ensanche de Vallecas - La Gavia  Madrid',
#        'Piso en calle de Maldonado  Lista  Madrid',
#        'Piso en calle Martín Muñoz de las Posadas  7  Ensanche de Vallecas - La Gavia  Madrid',
#        'Piso en calle la Canción del Olvido  62  Los Ángeles  Madrid',
#        'Ático en calle Víctor Hugo  5  Chueca-Justicia  Madrid',
#        'Piso en calle de Caramuel  Puerta del Ángel  Madrid',
#        'Piso en calle de Orense  12  Cuatro Caminos  Madrid',
#        'Piso en calle del Lucero del Alba  1  Los Ángeles  Madrid',
#        'Piso en calle de José María de Pereda  Ventas  Madrid',
#        'Piso en calle Arte Pop  8  Ensanche de Vallecas - La Gavia  Madrid',
#        'Piso en calle de Rafael Herrera  11  Castilla  Madrid',
#        'Piso en bulevar de José Prat  Valdebernardo - Valderrivas  Madrid',
#        'Piso en calle Víctor Andrés Belaunde  Bernabéu-Hispanoamérica  Madrid',
#        'Piso en calle de Atocha  Huertas-Cortes  Madrid',
#        'Piso en Corredera Baja de San Pablo  47  Malasaña-Universidad  Madrid',
#        'Piso en Castellana  Madrid',
#        'Piso en calle de Alcalá  Ventas  Madrid',
#        'Piso en Colina  Madrid',
#        'Piso en calle de Ricardo Ortiz  Ventas  Madrid',
#        'Piso en calle de Modesto Lafuente  Nuevos Ministerios-Ríos Rosas  Madrid',
#        'Piso en calle del Doctor Vallejo  Quintana  Madrid',
#        'Casa o chalet independiente en Armonía  24  Palomas  Madrid',
#        'Piso en Numancia  Madrid',
#        'Piso en calle de Linneo  Imperial  Madrid',
#        'Piso en calle Jerez de los Caballeros  2  Casco Histórico de Barajas  Madrid',
#        'Piso en calle de los Yébenes  Aluche  Madrid',
#        'Piso en calle de Miguel Ángel  3  Almagro  Madrid',
#        'Piso en Rejas  Madrid', 'Piso en Chueca-Justicia  Madrid',
#        'Piso en calle de las Islas Cíes  Peñagrande  Madrid',
#        'Piso en calle del Real Madrid  Puerta Bonita  Madrid',
#        'Chalet pareado en Conde Orgaz-Piovera  Madrid',
#        'Piso en calle de los Tejedores  Amposta  Madrid',
#        'Piso en calle de Ayala  Goya  Madrid',
#        "Piso en calle de O'Donnell  Goya  Madrid",
#        'Piso en calle de Santa Cruz de Mudela  Almendrales  Madrid',
#        'Piso en calle de Lagasca  Recoletos  Madrid',
#        'Piso en calle de Francisco Suárez  Nueva España  Madrid',
#        'Piso en calle del Espejo  Palacio  Madrid',
#        'Dúplex en calle de Lagasca  Castellana  Madrid',
#        'Piso en Niño Jesús  Madrid', 'Piso en Nueva España  Madrid',
#        'Piso en calle del Porvenir  Fuente del Berro  Madrid',
#        'Ático en calle Anna Frank  19  El Cañaveral  Madrid',
#        'Piso en calle del Limón  Malasaña-Universidad  Madrid',
#        'Casa o chalet independiente en Valdemarín  Madrid',
#        'Piso en calle de Alucas  4  Pueblo Nuevo  Madrid',
#        'Piso en Vallehermoso  Madrid',
#        'Piso en calle drácena  Nueva España  Madrid',
#        'Ático en calle Arroyo del Cañaveral  66  El Cañaveral  Madrid',
#        'Piso en calle del Conde de Peñalver  83  Lista  Madrid',
#        'Piso en calle de Lagasca  99  Castellana  Madrid',
#        'Piso en calle Provisiones  Lavapiés-Embajadores  Madrid',
#        'Piso en calle de las Viñas del Rio  16  Butarque  Madrid',
#        'Ático en Trafalgar  Madrid',
#        'Ático en calle de Núñez de Balboa  Castellana  Madrid',
#        'Ático en calle de Palafox  Trafalgar  Madrid',
#        'Piso en calle de Don Ramón de la Cruz  Castellana  Madrid',
#        'Piso en calle de Diego de León  Lista  Madrid',
#        'Dúplex en calle de la Buganvilla  4  Castilla  Madrid',
#        'Piso en calle de Benito Gutiérrez  35  Argüelles  Madrid',
#        'Piso en Fuente del Berro  Madrid',
#        'Piso en aurora  Valdezarza  Madrid',
#        'Piso en calle de Caleruega  50  Costillares  Madrid',
#        'Piso en Puerta Bonita  Madrid', 'Piso en El Viso  Madrid',
#        'Piso en plaza de Monterrey  Apóstol Santiago  Madrid',
#        'Estudio en cuesta de las Descargas  8  Palacio  Madrid',
#        'Piso en calle de María de Molina  Castellana  Madrid',
#        'Piso en calle Félix Boix  32  Nueva España  Madrid',
#        'Piso en paseo Marqués de Monistrol  Puerta del Ángel  Madrid',
#        'Piso en avenida de Portugal  177  Puerta del Ángel  Madrid',
#        'Piso en calle Embajadores  Lavapiés-Embajadores  Madrid',
#        'Piso en calle de Carlos Arniches  Lavapiés-Embajadores  Madrid',
#        'Chalet adosado en Ensanche de Vallecas - La Gavia  Madrid',
#        'Piso en calle de Hermosilla  Recoletos  Madrid',
#        'Piso en calle de Núñez de Balboa  Recoletos  Madrid',
#        'Piso en calle de José Antonio Navarrete  Conde Orgaz-Piovera  Madrid',
#        'Piso en calle de Isabel Clara Eugenia  43  Sanchinarro  Madrid',
#        'Piso en calle de Lombía  Goya  Madrid',
#        'Piso en avenida de Machupichu  Conde Orgaz-Piovera  Madrid',
#        'Piso en calle Manuel Aleixandre  12  Legazpi  Madrid',
#        'Piso en plaza de Cascorro  Lavapiés-Embajadores  Madrid',
#        'Piso en avenida del Papa Negro  Conde Orgaz-Piovera  Madrid',
#        'Piso en calle de Fernando VI  Chueca-Justicia  Madrid',
#        'Piso en Lucero  Madrid',
#        'Piso en Castillo de Cadanchu  Las Tablas  Madrid',
#        'Piso en Montecarmelo  Madrid',
#        'Piso en calle de los Relatores  10  Lavapiés-Embajadores  Madrid',
#        'Piso en Sol  Madrid', 'Piso en calle de la Montera  Sol  Madrid',
#        'Piso en calle del Acuerdo  Malasaña-Universidad  Madrid',
#        'Piso en Artesa de Segre  Ciudad Universitaria  Madrid',
#        'Ático en calle de Mauricio Legendre  39  Castilla  Madrid',
#        'Piso en calle de Arturo Soria  Costillares  Madrid',
#        'Piso en calle de Cáceres  Chopera  Madrid',
#        'Ático en calle Nenúfar  6  Berruguete  Madrid',
#        'Ático en Nuevos Ministerios-Ríos Rosas  Madrid',
#        'Piso en calle de San Nicolás  Palacio  Madrid',
#        'Piso en Palomas  Madrid',
#        'Piso en calle de Fernández de los Ríos  Gaztambide  Madrid',
#        'Piso en Ciudad Jardín  Madrid',
#        'Piso en calle Almagro  30  Almagro  Madrid',
#        'Piso en calle Bahía de Palma  14  Campo de las Naciones-Corralejos  Madrid',
#        'Dúplex en Conde Orgaz-Piovera  Madrid',
#        'Piso en calle de los Cabestreros  Lavapiés-Embajadores  Madrid',
#        'Ático en Recoletos  Madrid',
#        'Piso en calle de Sánchez Barcáiztegui  9  Pacífico  Madrid',
#        'Piso en calle Pintor Ignacio de Zuloaga  16  Sanchinarro  Madrid',
#        'Piso en calle de Núñez de Balboa  Castellana  Madrid',
#        'Piso en calle de Trueba y Fernández  Bernabéu-Hispanoamérica  Madrid',
#        'Piso en plaza Nuestra Señora del Pilar  4  Prosperidad  Madrid',
#        'Piso en Entrevías  Madrid',
#        'Piso en avenida del Ensanche de Vallecas  Ensanche de Vallecas - La Gavia  Madrid',
#        'Piso en calle de Ferrer del Río  Guindalera  Madrid',
#        'Piso en calle Del Padre Claret  Prosperidad  Madrid',
#        'Piso en calle de Yécora  Rejas  Madrid',
#        'Piso en calle de Ayala  71  Goya  Madrid',
#        'Piso en san secundino  Ventas  Madrid',
#        'Ático en calle de Cristóbal Bordiú  Nuevos Ministerios-Ríos Rosas  Madrid',
#        'Piso en tubas  Pau de Carabanchel  Madrid',
#        'Chalet adosado en Conde Orgaz-Piovera  Madrid',
#        'Piso en calle Arroyo del Cañaveral  66  El Cañaveral  Madrid',
#        'Piso en calle de Vallehermoso  Vallehermoso  Madrid',
#        'Casa o chalet independiente en calle del Sotillo  Conde Orgaz-Piovera  Madrid',
#        'Piso en avenida de Brasilia  Guindalera  Madrid',
#        'Piso en calle de Isabel Clara Eugenia  39  Sanchinarro  Madrid',
#        'Piso en Arcos  Madrid',
#        'Casa o chalet independiente en ronda de la Abubilla  1  Conde Orgaz-Piovera  Madrid',
#        'Ático en calle Secoya  3  Pau de Carabanchel  Madrid',
#        'Piso en Cuzco-Castillejos  Madrid',
#        'Piso en calle de la Princesa  3  Argüelles  Madrid',
#        'Estudio en calle de Calatrava  Palacio  Madrid',
#        'Ático en puerta del Sol  Sol  Madrid',
#        'Piso en calle de Velázquez  Castellana  Madrid',
#        'Piso en calle de Meléndez Valdés  Gaztambide  Madrid',
#        'Piso en calle Arroyo del Cañaveral  64  El Cañaveral  Madrid',
#        'Piso en calle de la Paloma  Palacio  Madrid',
#        'Ático en calle Lozoya  Arapiles  Madrid',
#        'Piso en calle de Aristóteles  1  San Pascual  Madrid',
#        'Piso en avenida de la Reina Victoria  Vallehermoso  Madrid',
#        'Piso en Ciudad Universitaria  Madrid',
#        'Piso en plaza de Santa Catalina de los Donados  Sol  Madrid',
#        'Piso en paseo de la Direccion  161  Valdeacederas  Madrid',
#        'Piso en calle de Diego de León  52  Lista  Madrid',
#        'Dúplex en calle Ana de Austria  101  Sanchinarro  Madrid',
#        'Piso en avenida del Doctor Federico Rubio y Galí  Ciudad Universitaria  Madrid',
#        'Piso en calle de María Panés  Nuevos Ministerios-Ríos Rosas  Madrid',
#        'Piso en paseo De La Castellana  Ventilla-Almenara  Madrid',
#        'Piso en Vallehermoso  Arapiles  Madrid',
#        'Piso en calle de Apolonio Morales  Nueva España  Madrid',
#        'Piso en Prosperidad  Madrid',
#        'Dúplex en calle de Manuel Tovar  Tres Olivos - Valverde  Madrid',
#        'Ático en Fuente del Berro  Madrid',
#        'Ático en Bernabéu-Hispanoamérica  Madrid',
#        'Piso en Valdemarín  Madrid',
#        'Piso en paseo del General Martínez Campos  Almagro  Madrid',
#        'Piso en Quintana  Madrid',
#        'Piso en calle de Fernández de la Hoz  Almagro  Madrid',
#        'Piso en calle de Castelló  Castellana  Madrid',
#        'Piso en calle del Príncipe de Vergara  109  El Viso  Madrid',
#        'Piso en pasaje de Bisbal  Fuente del Berro  Madrid',
#        'Piso en calle de Juan Duque  10  Imperial  Madrid',
#        'Piso en calle de Juan Álvarez Mendizábal  44  Argüelles  Madrid',
#        'Ático en calle del Cactus  1  Berruguete  Madrid',
#        'Piso en calle del Olivar  13  Lavapiés-Embajadores  Madrid',
#        'Piso en calle Arturo Soria  328  Costillares  Madrid',
#        'Piso en calle de Guipúzcoa  6  Cuatro Caminos  Madrid',
#        'Estudio en calle de Buenavista  20  Lavapiés-Embajadores  Madrid',
#        'Piso en calle de la Costa Brava  Mirasierra  Madrid',
#        'Ático en calle del Príncipe de Vergara  211  El Viso  Madrid',
#        'Piso en Los Cármenes  Madrid',
#        'Piso en paseo de la Dirección  161  Valdeacederas  Madrid',
#        'Piso en calle santa teresa  3  Chueca-Justicia  Madrid',
#        'Estudio en calle de Sor María de Ágreda  Ventas  Madrid',
#        'Piso en calle de Castelló  Recoletos  Madrid',
#        'Piso en calle de Lagasca  Castellana  Madrid',
#        'Piso en calle de Triana  35  Nueva España  Madrid',
#        'Estudio en calle de Triana  35  Nueva España  Madrid',
#        'Piso en calle de Don Ramón de la Cruz  Recoletos  Madrid',
#        'Piso en Concepción  Madrid',
#        'Piso en calle San Martín de Porres  Ciudad Universitaria  Madrid'],
#       dtype=object)

# %%
barrios_madrid = ['Arganzuela', 'Acacias', 'Atocha', 'Chopera', 'Delicias', 'Imperial', 'Legazpi', 'Palos de Moguer',
                  'Barajas', 'Aeropuerto', 'Alameda de Osuna', 'Casco Histórico de Barajas', 'Corralejos', 'Timón',
                  'Carabanchel', 'Comillas', 'Opañel', 'San Isidro', 'Vista Alegre', 'Puerta Bonita', 'Buenavista', 'Abrantes',
                  'Centro', 'Cortes', 'Embajadores', 'Justicia', 'Palacio', 'Sol', 'Universidad',
                  'Chamartín', 'El Viso', 'Castilla', 'Ciudad Jardín', 'Hispanoamérica', 'Nueva España', 'Prosperidad',
                  'Chamberí', 'Almagro', 'Arapiles', 'Gaztambide', 'Ríos Rosas', 'Trafalgar', 'Vallehermoso',
                  'Ciudad Lineal', 'Atalaya', 'Colina', 'Concepción', 'Costillares', 'Pueblo Nuevo', 'Quintana', 'San Pascual', 'San Juan Bautista', 'Ventas',
                  'Fuencarral – El Pardo', 'Del Pilar', 'El Goloso', 'El Pardo', 'Fuentelarreina', 'La Paz', 'Mirasierra', 'Peñagrande', 'Valverde',
                  'Hortaleza', 'Apóstol Santiago', 'Canillas', 'Palomas', 'Pinar del Rey', 'Piovera', 'Valdefuentes',
                  'Latina', 'Aluche', 'Campamento', 'Cármenes', 'Cuatro Vientos', 'Las Águilas', 'Lucero', 'Puerta del Ángel',
                  'Moncloa – Aravaca', 'Aravaca', 'Argüelles', 'Casa de Campo', 'Ciudad Universitaria', 'El Plantío', 'Valdematín', 'Valdezarza',
                  'Moratalaz', 'Fontarrón', 'Horcajo', 'Marroquina', 'Media Legua', 'Pavones', 'Vinateros',
                  'Puente de Vallecas', 'Entrevías', 'Numancia', 'Palomeras Bajas', 'Palomeras Sureste', 'Portazgo', 'San Diego',
                  'Retiro', 'Adelfas', 'Estrella', 'Ibiza', 'Jerónimos', 'Niño Jesús', 'Pacífico',
                  'Salamanca', 'Castellana', 'Fuente del Berro', 'Goya', 'Guindalera', 'Lista', 'Recoletos',
                  'San Blas', 'Amposta', 'Arcos', 'Canillejas', 'Hellín', 'Rejas', 'Rosas', 'Salvador', 'Simancas',
                  'Tetuán', 'Almenara', 'Bellas Vistas', 'Berruguete', 'Castillejos', 'Cuatro Caminos', 'Valdeacederas',
                  'Usera', 'Almendrales', 'Moscardó', 'Orcasitas', 'Orcasur', 'Pradolongo', 'San Fermín', 'Zofío',
                  'Vicálvaro', 'Ambroz', 'Casco Histórico de Vicalvaro',
                  'Villa de Vallecas', 'Casco Histórico de Vallecas', 'Santa Eugenia',
                  'Villaverde', 'Butarque', 'Los Ángeles', 'Los Rosales', 'San Andrés', 'San Cristóbal']
